# %%
# Define the Employee class
class Employee:
    def _init_(
        self,
        designation: str = "Developer",
        frontend: bool = False,
        backend: bool = False
    ):
        self.designation = designation
        self.frontend = frontend
        self.backend = backend

    def _repr_(self):
        return "{} - Frontend: {}, Backend: {}".format(self.designation, self.frontend, self.backend)

    def verifier(self):
        if self.frontend and self.backend:
            return "Full Stack Developer"
        elif self.frontend:
            return "Frontend Developer"
        elif self.backend:
            return "Backend Developer"
        else:
            return "Not a Developer"

# Test the Employee class with user-defined values
if __name__ == "_main_":
    # Get user input
    frontend_input = input("Is the employee a Frontend Developer? (yes/no): ").strip().lower()
    backend_input = input("Is the employee a Backend Developer? (yes/no): ").strip().lower()

    # Convert inputs to boolean values
    frontend = True if frontend_input == "yes" else False
    backend = True if backend_input == "yes" else False

    # Create an Employee object
    employee = Employee(frontend=frontend, backend=backend)

    # Print the employee's designation type
    print("Designation Type:", employee.verifier())
